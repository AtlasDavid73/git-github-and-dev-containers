# %%
class Order:
    def __init__(self, id):
        self.id = id

class OrderStack:
    def __init__(self):
        self.stack = []

    def add_order(self, order):
        self.stack.append(order)
        print(f"Order {order.id} added to the stack.")

    def process_order(self):
        if self.stack:
            order = self.stack.pop()
            print(f"Processed {order.id}")
        else:
            print("No orders to process.")

    def current_stack(self):
        return [order.id for order in self.stack]

def main():
    order_stack = OrderStack()

    while True:
        print(f"\nCurrent Stack: {order_stack.current_stack()}")
        print("1: Add Order, 2: Process Order, 3: Show Current Stack, 4: Exit")
        choice = input("Enter your choice: ")

        if choice == "1":
            order_id = input("Enter Order ID: ")
            new_order = Order(order_id)
            order_stack.add_order(new_order)

        elif choice == "2":
            order_stack.process_order()

        elif choice == "3":
            print(f"Current Stack: {order_stack.current_stack()}")

        elif choice == "4":
            print("Exiting system.")
            break

        else:
            print("Invalid choice. Please try again.")

main()
2223
# Out:
# Current Stack: []
# 1: Add Order, 2: Process Order, 3: Show Current Stack, 4: Exit
# Invalid choice. Please try again.
#
# Current Stack: []
# 1: Add Order, 2: Process Order, 3: Show Current Stack, 4: Exit
# Order 11 added to the stack.
#
# Current Stack: ['11']
# 1: Add Order, 2: Process Order, 3: Show Current Stack, 4: Exit
# Order 1 added to the stack.
#
# Current Stack: ['11', '1']
# 1: Add Order, 2: Process Order, 3: Show Current Stack, 4: Exit
# Invalid choice. Please try again.
#
# Current Stack: ['11', '1']
# 1: Add Order, 2: Process Order, 3: Show Current Stack, 4: Exit
# Invalid choice. Please try again.
#
# Current Stack: ['11', '1']
# 1: Add Order, 2: Process Order, 3: Show Current Stack, 4: Exit
# Order Order002 added to the stack.
#
# Current Stack: ['11', '1', 'Order002']
# 1: Add Order, 2: Process Order, 3: Show Current Stack, 4: Exit
# Invalid choice. Please try again.
#
# Current Stack: ['11', '1', 'Order002']
# 1: Add Order, 2: Process Order, 3: Show Current Stack, 4: Exit
# Current Stack: ['11', '1', 'Order002']
#
# Current Stack: ['11', '1', 'Order002']
# 1: Add Order, 2: Process Order, 3: Show Current Stack, 4: Exit
# Processed Order002
#
# Current Stack: ['11', '1']
# 1: Add Order, 2: Process Order, 3: Show Current Stack, 4: Exit
# Processed 1
#
# Current Stack: ['11']
# 1: Add Order, 2: Process Order, 3: Show Current Stack, 4: Exit
# Invalid choice. Please try again.
#
# Current Stack: ['11']
# 1: Add Order, 2: Process Order, 3: Show Current Stack, 4: Exit
# Processed 11
#
# Current Stack: []
# 1: Add Order, 2: Process Order, 3: Show Current Stack, 4: Exit
# Invalid choice. Please try again.
#
# Current Stack: []
# 1: Add Order, 2: Process Order, 3: Show Current Stack, 4: Exit
# Exiting system.
# 2223
